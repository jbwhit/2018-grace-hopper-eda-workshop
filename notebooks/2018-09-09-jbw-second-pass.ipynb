# %% [markdown]
# # Some hypotheses/ideas to test
#
#  - Maybe stick to just the paintings at MoMA?
#  - gender ratio of works over time
#  - the directors of departments have a strong influence on makeup of the exhibitions (speculative/unclear how to analyze this question easily)
#  - Size of paintings vs gender or vs time
#  - Analyze the thumbnails for color choices over time / by gender
#  - age when artists die
#  - age when artists get first artwork into MoMA
#  - Should we specify only catalogued things count?
#  - Do bequeathments skew the numbers?
#
#
# ## Todo
#
#  - Add link to [![DOI](https://zenodo.org/badge/doi/10.5281/zenodo.1324595.svg)](http://dx.doi.org/10.5281/zenodo.1324595) to powerpoint
#
# [DOI](http://dx.doi.org/10.5281/zenodo.1324595)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import sys
import os
import missingno as msno

pd.options.display.max_columns = None
pd.options.display.max_rows = None

sns.set();
sns.set_context('poster', font_scale=1.3)

# %%
# load raw data
full_artists = pd.read_csv("../data/Artists.csv")
full_artworks = pd.read_csv("../data/Artworks.csv")

# %%
# cleaned data
artists = full_artists.copy()
works = full_artworks.copy()

# %%
# normalize the columns names
artists.columns = [
    col.replace(' ', '_').replace("(", "").replace(")", "").replace(
        ".", "").lower() for col in artists.columns
]
works.columns = [
    col.replace(' ', '_').replace("(", "").replace(")", "").replace(
        ".", "").lower() for col in works.columns
]

# %%
for col in artists.columns:
    print(col)
# Out:
# constituentid
# displayname
# artistbio
# nationality
# gender
# begindate
# enddate
# wiki_qid
# ulan

# %%
for col in works.columns:
    print(col)
# Out:
# title
# artist
# constituentid
# artistbio
# nationality
# begindate
# enddate
# gender
# date
# medium
# dimensions
# creditline
# accessionnumber
# classification
# department
# dateacquired
# cataloged
# objectid
# url
# thumbnailurl
# circumference_cm
# depth_cm
# diameter_cm
# height_cm
# length_cm
# weight_kg
# width_cm
# seat_height_cm
# duration_sec

# %%
works.describe()
# Out:
#             objectid  circumference_cm      depth_cm  diameter_cm  \
# count  128667.000000         10.000000  11488.000000  1356.000000
# mean    85411.890088         44.868020     18.595849    23.424358
# std     64196.642874         28.631604     57.873050    46.192935
# min         2.000000          9.900000      0.000000     0.635000
# 25%     33898.500000         23.500000      0.000000     7.680004
# 50%     69308.000000         36.000000      1.270003    13.335000
# 75%    131211.500000         71.125000     14.000000    25.000000
# max    290159.000000         83.800000   1808.483617   914.400000
#
#            height_cm    length_cm      weight_kg       width_cm  \
# count  110435.000000   666.000000     292.000000  109524.000000
# mean       37.521945    85.142523    1274.855486      37.533461
# std        48.564939   346.609172   11976.608071      67.801179
# min         0.000000     0.000000       0.090000       0.000000
# 25%        17.900000    15.300000       5.613300      17.500000
# 50%        27.800000    24.115000      19.844900      25.400000
# 75%        43.800000    60.960122      72.462100      43.300000
# max      9140.000000  8321.056600  185067.585957    9144.000000
#
#        seat_height_cm  duration_sec
# count             0.0  3.094000e+03
# mean              NaN  7.811603e+03
# std               NaN  1.183128e+05
# min               NaN  0.000000e+00
# 25%               NaN  2.130000e+02
# 50%               NaN  7.200000e+02
# 75%               NaN  3.658250e+03
# max               NaN  6.283065e+06

# %%
artists.describe()
# Out:
#           begindate       enddate          ulan
# count  15644.000000  15644.000000  2.938000e+03
# mean    1459.735426    619.970979  5.000744e+08
# std      830.128157    916.861353  8.658342e+04
# min        0.000000      0.000000  5.000000e+08
# 25%     1819.000000      0.000000  5.000176e+08
# 50%     1922.000000      0.000000  5.000331e+08
# 75%     1949.000000   1953.000000  5.001142e+08
# max     2017.000000   2018.000000  5.003566e+08

# %% [markdown]
# These begin and end dates don't look particularly correct. What's going on?

# %%
artists.head()
# Out:
#   constituentid      displayname            artistbio nationality gender  \
# 0             1   Robert Arneson  American, 1930–1992    American   male
# 1             2   Doroteo Arnaiz   Spanish, born 1936     Spanish   male
# 2             3      Bill Arnold  American, born 1941    American   male
# 3             4  Charles Arnoldi  American, born 1946    American   male
# 4             5      Per Arnoldi    Danish, born 1941      Danish   male
#
#    begindate  enddate  wiki_qid         ulan
# 0       1930     1992       NaN          NaN
# 1       1936        0       NaN          NaN
# 2       1941        0       NaN          NaN
# 3       1946        0  Q1063584  500027998.0
# 4       1941        0       NaN          NaN

# %% [markdown]
# Ah, it appears that missing values are given the value of 0. Let's check if that makes sense.

# %%
artists[artists.begindate > 0].min()
# Out:
# constituentid                                       1
# displayname      (follower of) José-Guadalupe  Posada
# begindate                                        1730
# enddate                                             0
# ulan                                            5e+08
# dtype: object

# %%
artists[artists.enddate > 0].sort_values(by='enddate').head()
# Out:
#       constituentid                   displayname           artistbio  \
# 5626           6278               Josiah Wedgwood  British, 1730–1795
# 2027           2274             Francisco de Goya  Spanish, 1746–1828
# 482             542                 Thomas Bewick  British, 1753–1828
# 7098           8067                Robert Adamson  British, 1821–1848
# 11520         34418  Louis-Jacques-Mandé Daguerre   French, 1787–1851
#
#       nationality gender  begindate  enddate wiki_qid         ulan
# 5626      British   male       1730     1795  Q319331  500062605.0
# 2027      Spanish   male       1746     1828    Q5432  500118936.0
# 482       British   male       1753     1828      NaN          NaN
# 7098      British   male       1821     1848  Q509636  500010587.0
# 11520      French   male       1787     1851  Q131405  500022993.0

# %% [markdown]
# Ok, so artist who lived the farthest back in history in the collection at MoMA is Josiah Wedgwood.

# %%
artists.head()
# Out:
#   constituentid      displayname            artistbio nationality gender  \
# 0             1   Robert Arneson  American, 1930–1992    American   male
# 1             2   Doroteo Arnaiz   Spanish, born 1936     Spanish   male
# 2             3      Bill Arnold  American, born 1941    American   male
# 3             4  Charles Arnoldi  American, born 1946    American   male
# 4             5      Per Arnoldi    Danish, born 1941      Danish   male
#
#    begindate  enddate  wiki_qid         ulan
# 0       1930     1992       NaN          NaN
# 1       1936        0       NaN          NaN
# 2       1941        0       NaN          NaN
# 3       1946        0  Q1063584  500027998.0
# 4       1941        0       NaN          NaN

# %%
Wait, now

# %%
works.artist.nunique()
# Out:
# 14116

# %%
artists.constituentid.nunique()
# Out:
# 15644

# %% [markdown]
# More artists than works?

# %% [markdown]
# ## Questions
#
# Think about the column names -- be skeptical!
#
# If you have modeling questions (try to break out the target variable from the analysis ASAP).

# %%
works.cataloged.value_counts().head(100)
# Out:
# Y    77510
# N    57808
# Name: cataloged, dtype: int64

# %%
works.classification.value_counts().head(100)
# Out:
# Photograph                        31353
# Print                             31348
# Illustrated Book                  26646
# Drawing                           12295
# Design                            11789
# Mies van der Rohe Archive          3402
# Architecture                       3151
# Video                              2670
# Film                               2545
# Painting                           2293
# Sculpture                          1690
# Multiple                           1133
# Periodical                          899
# Installation                        812
# Frank Lloyd Wright Archive          808
# Audio                               787
# (not assigned)                      751
# Ephemera                            401
# Work on Paper                       395
# Media                                41
# Performance                          29
# Textile                              27
# Poster                               24
# Collage                               9
# Software                              5
# Photography Research/Reference        5
# Film (object)                         2
# Graphic Design                        2
# Furniture and Interiors               2
# Publication                           1
# Product Design                        1
# Architectural Model                   1
# News Clipping                         1
# Name: classification, dtype: int64

# %% [markdown]
# ### Wow! That's a lot of photographs!
#
# There are 13 times more photographs than of paintings at MoMA. The photographer Eugène Atget has 5,044 photographs at MoMA. This is more than double the total number of paintings at MoMA. If you want to simply count artwork at MoMA to get a sense of gender disparity, you might find that the naive way of counting things will skew things wildly.

# %% [markdown]
# What does it mean to be cataloged vs not? How can it be in this dataset if not cataloged?
#
#
# Should we include it not? -- Don't look at the answer you want to get (the gender distribution of cataloged vs not-cataloged) to decide how to split the data.

# %% [markdown]
# # Data Issues
#
# ## Sanity Check: Acquisition dates
#
# ### Data error
# "The Museum of Modern Art (MoMA) acquired its first works in 1929, the year it was established." --https://github.com/MuseumofModernArt/collection

# %%
works[works.dateacquired < '1928-01-01']
# Out:
#                             title     artist constituentid         artistbio  \
# 129764  Songs for Swinging Larvae  Residents         34673  (USA, est. 1972)
#
#        nationality begindate enddate gender  date medium dimensions  \
# 129764  (American)    (1972)     (0)     ()  1982  Video        NaN
#
#                 creditline accessionnumber classification department  \
# 129764  Gift of the Artist          818629          Video       Film
#
#        dateacquired cataloged  objectid  url thumbnailurl  circumference_cm  \
# 129764   1216-10-18         N    215774  NaN          NaN               NaN
#
#         depth_cm  diameter_cm  height_cm  length_cm  weight_kg  width_cm  \
# 129764       NaN          NaN        NaN        NaN        NaN       NaN
#
#         seat_height_cm  duration_sec
# 129764             NaN           NaN

# %%
# modify the cleaned version of the data to exclude (or fix) troublesome data.
works = works[works.dateacquired >= '1928-01-01'].copy()

# %%
# Set the date to a datetime type
works['dateacquired'] = pd.to_datetime(works['dateacquired'])

# %%
works.shape
# Out:
# (128667, 29)

# %% [markdown]
# ## Gender assigned inconsistently
#
# ### Data error
#
# Male/Female both capitalized and not-capitalized.

# %%
artists.gender.value_counts()
# Out:
# Male      10149
# Female     2359
# male         15
# female        1
# Name: gender, dtype: int64

# %%
artists['gender'] = artists.gender.str.lower()

# %%
artists.gender.value_counts()
# Out:
# male      10164
# female     2360
# Name: gender, dtype: int64

# %%
artists.head()
# Out:
#    constituentid      displayname            artistbio nationality gender  \
# 0              1   Robert Arneson  American, 1930–1992    American   male
# 1              2   Doroteo Arnaiz   Spanish, born 1936     Spanish   male
# 2              3      Bill Arnold  American, born 1941    American   male
# 3              4  Charles Arnoldi  American, born 1946    American   male
# 4              5      Per Arnoldi    Danish, born 1941      Danish   male
#
#    begindate  enddate  wiki_qid         ulan
# 0       1930     1992       NaN          NaN
# 1       1936        0       NaN          NaN
# 2       1941        0       NaN          NaN
# 3       1946        0  Q1063584  500027998.0
# 4       1941        0       NaN          NaN

# %%
works.head()
# Out:
#                                                title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria, Ele...
# 1  City of Music, National Superior Conservatory ...
# 2  Villa near Vienna Project, Outside Vienna, Aus...
# 3  The Manhattan Transcripts Project, New York, N...
# 4  Villa, project, outside Vienna, Austria, Exter...
#
#                      artist constituentid  \
# 0               Otto Wagner          6210
# 1  Christian de Portzamparc          7470
# 2                Emil Hoppe          7605
# 3           Bernard Tschumi          7056
# 4                Emil Hoppe          7605
#
#                                    artistbio nationality begindate enddate  \
# 0                      (Austrian, 1841–1918)  (Austrian)    (1841)  (1918)
# 1                        (French, born 1944)    (French)    (1944)     (0)
# 2                      (Austrian, 1876–1957)  (Austrian)    (1876)  (1957)
# 3  (French and Swiss, born Switzerland 1944)          ()    (1944)     (0)
# 4                      (Austrian, 1876–1957)  (Austrian)    (1876)  (1957)
#
#    gender  date                                             medium  \
# 0  (Male)  1896      Ink and cut-and-pasted painted pages on paper
# 1  (Male)  1987                  Paint and colored pencil on print
# 2  (Male)  1903  Graphite, pen, color pencil, ink, and gouache ...
# 3  (Male)  1980  Photographic reproduction with colored synthet...
# 4  (Male)  1903  Graphite, color pencil, ink, and gouache on tr...
#
#                            dimensions  \
# 0  19 1/8 x 66 1/2" (48.6 x 168.9 cm)
# 1       16 x 11 3/4" (40.6 x 29.8 cm)
# 2   13 1/2 x 12 1/2" (34.3 x 31.8 cm)
# 3           20 x 20" (50.8 x 50.8 cm)
# 4    15 1/8 x 7 1/2" (38.4 x 19.1 cm)
#
#                                           creditline accessionnumber  \
# 0  Fractional and promised gift of Jo Carole and ...        885.1996
# 1  Gift of the architect in honor of Lily Auchinc...          1.1995
# 2             Gift of Jo Carole and Ronald S. Lauder          1.1997
# 3  Purchase and partial gift of the architect in ...          2.1995
# 4             Gift of Jo Carole and Ronald S. Lauder          2.1997
#
#   classification             department dateacquired cataloged  objectid  \
# 0   Architecture  Architecture & Design   1996-04-09         Y         2
# 1   Architecture  Architecture & Design   1995-01-17         Y         3
# 2   Architecture  Architecture & Design   1997-01-15         Y         4
# 3   Architecture  Architecture & Design   1995-01-17         Y         5
# 4   Architecture  Architecture & Design   1997-01-15         Y         6
#
#                                       url  \
# 0  http://www.moma.org/collection/works/2
# 1  http://www.moma.org/collection/works/3
# 2  http://www.moma.org/collection/works/4
# 3  http://www.moma.org/collection/works/5
# 4  http://www.moma.org/collection/works/6
#
#                                         thumbnailurl  circumference_cm  \
# 0  http://www.moma.org/media/W1siZiIsIjU5NDA1Il0s...               NaN
# 1  http://www.moma.org/media/W1siZiIsIjk3Il0sWyJw...               NaN
# 2  http://www.moma.org/media/W1siZiIsIjk4Il0sWyJw...               NaN
# 3  http://www.moma.org/media/W1siZiIsIjEyNCJdLFsi...               NaN
# 4  http://www.moma.org/media/W1siZiIsIjEyNiJdLFsi...               NaN
#
#    depth_cm  diameter_cm  height_cm  length_cm  weight_kg  width_cm  \
# 0       NaN          NaN    48.6000        NaN        NaN  168.9000
# 1       NaN          NaN    40.6401        NaN        NaN   29.8451
# 2       NaN          NaN    34.3000        NaN        NaN   31.8000
# 3       NaN          NaN    50.8000        NaN        NaN   50.8000
# 4       NaN          NaN    38.4000        NaN        NaN   19.1000
#
#    seat_height_cm  duration_sec
# 0             NaN           NaN
# 1             NaN           NaN
# 2             NaN           NaN
# 3             NaN           NaN
# 4             NaN           NaN

# %% [markdown]
# ## Tidy Data
#
# Hadley Wickham's concept of a tidy dataset summarized as:
#
#  - Each variable forms a column
#  - Each observation forms a row
#  - Each type of observational unit forms a table
#
# A longer paper describing this can be found in this [pdf](https://www.jstatsoft.org/article/view/v059i10/v59i10.pdf).
#
# Having datasets in this form allows for much simpler analyses. So the first step is to try and clean up the dataset into a tidy dataset.
#
# Notice that the `works` dataframe repeats artist data that we have in the artist table. We should discard these columns while maintaining the `constituentid` column so that we can join them if we need in the future.

# %%
keep_works_columns = [
    col for col in works.columns
    if (col not in artists.columns) and (col not in ['artist']) or (
        col == 'constituentid')
]

# %%
works = works[keep_works_columns].copy()

# %%
artists.describe()
# Out:
#           begindate       enddate          ulan
# count  15644.000000  15644.000000  2.938000e+03
# mean    1459.735426    619.970979  5.000744e+08
# std      830.128157    916.861353  8.658342e+04
# min        0.000000      0.000000  5.000000e+08
# 25%     1819.000000      0.000000  5.000176e+08
# 50%     1922.000000      0.000000  5.000331e+08
# 75%     1949.000000   1953.000000  5.001142e+08
# max     2017.000000   2018.000000  5.003566e+08

# %%
works.describe()
# Out:
#             objectid  circumference_cm      depth_cm  diameter_cm  \
# count  128667.000000         10.000000  11488.000000  1356.000000
# mean    85411.890088         44.868020     18.595849    23.424358
# std     64196.642874         28.631604     57.873050    46.192935
# min         2.000000          9.900000      0.000000     0.635000
# 25%     33898.500000         23.500000      0.000000     7.680004
# 50%     69308.000000         36.000000      1.270003    13.335000
# 75%    131211.500000         71.125000     14.000000    25.000000
# max    290159.000000         83.800000   1808.483617   914.400000
#
#            height_cm    length_cm      weight_kg       width_cm  \
# count  110435.000000   666.000000     292.000000  109524.000000
# mean       37.521945    85.142523    1274.855486      37.533461
# std        48.564939   346.609172   11976.608071      67.801179
# min         0.000000     0.000000       0.090000       0.000000
# 25%        17.900000    15.300000       5.613300      17.500000
# 50%        27.800000    24.115000      19.844900      25.400000
# 75%        43.800000    60.960122      72.462100      43.300000
# max      9140.000000  8321.056600  185067.585957    9144.000000
#
#        seat_height_cm  duration_sec
# count             0.0  3.094000e+03
# mean              NaN  7.811603e+03
# std               NaN  1.183128e+05
# min               NaN  0.000000e+00
# 25%               NaN  2.130000e+02
# 50%               NaN  7.200000e+02
# 75%               NaN  3.658250e+03
# max               NaN  6.283065e+06

# %% [markdown]
# ## Characterize missing data
#
# ### Artworks

# %%
msno.bar(works);

# %%
msno.matrix(works);

# %%
msno.heatmap(works);

# %%
msno.dendrogram(works);

# %% [markdown]
# ### Artists

# %%
msno.bar(artists);

# %%
msno.matrix(artists);

# %%
msno.heatmap(artists);

# %%
msno.dendrogram(artists);

# %% [markdown]
# ## Re-group data into functional derived tables

# %%
# needed to join 
artists['constituentid'] = artists.constituentid.astype(str)
works['constituentid'] = works.constituentid.astype(str)

# %%
artists.dtypes
# Out:
# constituentid     object
# displayname       object
# artistbio         object
# nationality       object
# gender            object
# begindate          int64
# enddate            int64
# wiki_qid          object
# ulan             float64
# dtype: object

# %%
combined = pd.merge(works, artists, how='inner', left_on='constituentid', right_on='constituentid')

# %%
combined.shape
# Out:
# (120603, 31)

# %%
works.shape
# Out:
# (128667, 23)

# %%
works[~works.constituentid.isin(combined.constituentid)].head(10)['constituentid']
# Out:
# 65                 6969, 8134
# 66                 6956, 6957
# 76           7661, 8131, 8180
# 107                 27, 24452
# 110          8102, 6703, 4312
# 111          8102, 6703, 4312
# 112          8102, 4312, 6703
# 113          8102, 6703, 4312
# 151          8707, 6951, 6952
# 154    6956, 7559, 7558, 6957
# Name: constituentid, dtype: object

# %%
# Multi-constituentids mean we miss ~6% of the artworks in the collection.
(works.shape[0] - combined.shape[0]) / works.shape[0] * 100
# Out:
# 6.267341276317937

# %%
combined.head()
# Out:
#                                                title constituentid  date  \
# 0  Ferdinandsbrücke Project, Vienna, Austria, Ele...          6210  1896
# 1                                           Armchair          6210  1902
# 2                                              Stool          6210  1904
# 3                                            Railing          6210  1899
# 4  City of Music, National Superior Conservatory ...          7470  1987
#
#                                           medium  \
# 0  Ink and cut-and-pasted painted pages on paper
# 1                        Beech wood and aluminum
# 2  Bent beech wood, molded plywood, and aluminum
# 3                              Painted cast-iron
# 4              Paint and colored pencil on print
#
#                                           dimensions  \
# 0                 19 1/8 x 66 1/2" (48.6 x 168.9 cm)
# 1  30 7/8 x 22 1/4 x 20 1/4" (78.5 x 56.5 x 51.5 ...
# 2            18 1/2 x 16 x 16" (47 x 40.6 x 40.6 cm)
# 3       28 1/4 x 46 1/2 x 3" (72.4 x 117.5 x 7.6 cm)
# 4                      16 x 11 3/4" (40.6 x 29.8 cm)
#
#                                           creditline accessionnumber  \
# 0  Fractional and promised gift of Jo Carole and ...        885.1996
# 1                Estée and Joseph Lauder Design Fund        479.1978
# 2                Estée and Joseph Lauder Design Fund        480.1978
# 3                      Dorothy Cullman Purchase Fund       1394.2001
# 4  Gift of the architect in honor of Lily Auchinc...          1.1995
#
#   classification             department dateacquired cataloged  objectid  \
# 0   Architecture  Architecture & Design   1996-04-09         Y         2
# 1         Design  Architecture & Design   1978-09-27         Y      4023
# 2         Design  Architecture & Design   1978-09-27         Y      4026
# 3   Architecture  Architecture & Design   2001-05-11         Y     82125
# 4   Architecture  Architecture & Design   1995-01-17         Y         3
#
#                                           url  \
# 0      http://www.moma.org/collection/works/2
# 1   http://www.moma.org/collection/works/4023
# 2   http://www.moma.org/collection/works/4026
# 3  http://www.moma.org/collection/works/82125
# 4      http://www.moma.org/collection/works/3
#
#                                         thumbnailurl  circumference_cm  \
# 0  http://www.moma.org/media/W1siZiIsIjU5NDA1Il0s...               NaN
# 1  http://www.moma.org/media/W1siZiIsIjIyOTgzNyJd...               NaN
# 2  http://www.moma.org/media/W1siZiIsIjU5MTMwIl0s...               NaN
# 3  http://www.moma.org/media/W1siZiIsIjYyMTEzIl0s...               NaN
# 4  http://www.moma.org/media/W1siZiIsIjk3Il0sWyJw...               NaN
#
#    depth_cm  diameter_cm  height_cm  length_cm  weight_kg  width_cm  \
# 0       NaN          NaN    48.6000        NaN        NaN  168.9000
# 1   51.5000          NaN    78.5000        NaN        NaN   56.5000
# 2   40.6401          NaN    46.9901        NaN        NaN   40.6401
# 3    7.6000          NaN    72.4000        NaN        NaN  117.5000
# 4       NaN          NaN    40.6401        NaN        NaN   29.8451
#
#    seat_height_cm  duration_sec               displayname  \
# 0             NaN           NaN               Otto Wagner
# 1             NaN           NaN               Otto Wagner
# 2             NaN           NaN               Otto Wagner
# 3             NaN           NaN               Otto Wagner
# 4             NaN           NaN  Christian de Portzamparc
#
#              artistbio nationality gender  begindate  enddate wiki_qid  \
# 0  Austrian, 1841–1918    Austrian   male       1841     1918   Q84287
# 1  Austrian, 1841–1918    Austrian   male       1841     1918   Q84287
# 2  Austrian, 1841–1918    Austrian   male       1841     1918   Q84287
# 3  Austrian, 1841–1918    Austrian   male       1841     1918   Q84287
# 4    French, born 1944      French   male       1944        0  Q312838
#
#           ulan
# 0  500016971.0
# 1  500016971.0
# 2  500016971.0
# 3  500016971.0
# 4  500024982.0

# %%
# another data issue
combined.gender.value_counts(dropna=False).head()
# Out:
# male      97848
# female    16205
# NaN        6550
# Name: gender, dtype: int64

# %%
def plot_gender_breakdown_over_time(df, title=None):
    """Calculates cumulative number of artworks by gender. Plots the values over time."""
    df = df.sort_values(by='dateacquired').set_index('dateacquired').copy()
    df['ones'] = 1
    works_man = df[df.gender.eq('male')].copy()
    works_woman = df[df.gender.eq('female')].copy()
    works_other = df[(~df.gender.eq('female'))
                              & (~df.gender.eq('male'))].copy()
    df['num_acquired'] = df.ones.cumsum()
    works_man['num_acquired'] = works_man.ones.cumsum()
    works_woman['num_acquired'] = works_woman.ones.cumsum()
    works_other['num_acquired'] = works_other.ones.cumsum()
    
    # Plot
    fig, ax = plt.subplots(figsize=(12, 8))
    (df['num_acquired']/1000).plot(ax=ax, label="Total")
    (works_man['num_acquired']/1000).plot(ax=ax, label="Male")
    (works_woman['num_acquired']/1000).plot(ax=ax, label="Female")
    # works_other['num_acquired'].plot(ax=ax, label="Multi-artist")
    ax.set_xlabel("Date Acquired")
    ax.set_ylabel("Number of Works (000s)")
    if title:
        ax.set_title(title)
    ax.legend()
    fig.tight_layout()

def plot_total_over_time(df, title=None):
    """Calculates cumulative number of artworks by gender. Plots the values over time."""
    df = df.sort_values(by='dateacquired').set_index('dateacquired').copy()
    df['ones'] = 1
    works_man = df[df.gender.eq('male')].copy()
    works_woman = df[df.gender.eq('female')].copy()
    works_other = df[(~df.gender.eq('female'))
                              & (~df.gender.eq('male'))].copy()
    df['num_acquired'] = df.ones.cumsum()
    works_man['num_acquired'] = works_man.ones.cumsum()
    works_woman['num_acquired'] = works_woman.ones.cumsum()
    works_other['num_acquired'] = works_other.ones.cumsum()
    
    # Plot
    fig, ax = plt.subplots(figsize=(12, 8))
    (df['num_acquired']/1000).plot(ax=ax, label="Total")
#     (works_man['num_acquired']/1000).plot(ax=ax, label="Male")
#     (works_woman['num_acquired']/1000).plot(ax=ax, label="Female")
    # works_other['num_acquired'].plot(ax=ax, label="Multi-artist")
    ax.set_xlabel("Date Acquired")
    ax.set_ylabel("Number of Works (000s)")
    if title:
        ax.set_title(title)
    ax.legend()
    fig.tight_layout()

def plot_gender_fraction_over_time(df, title=None):
    """Calculates the annual fraction of artworks by gender. Plots the ratio over time."""
    df = df.sort_values(by='dateacquired').set_index('dateacquired').copy()
    df['ones'] = 1
    works_man = df[df.gender.eq('male')].copy()
    works_woman = df[df.gender.eq('female')].copy()
    works_other = df[(~df.gender.eq('female'))
                              & (~df.gender.eq('male'))].copy()
    df['num_acquired'] = df.ones.cumsum()
    works_man['num_acquired'] = works_man.ones.cumsum()
    works_woman['num_acquired'] = works_woman.ones.cumsum()
    works_other['num_acquired'] = works_other.ones.cumsum()
    
    # Plot
    fig, ax = plt.subplots(figsize=(12, 8))
    time_group = 'Y'
    ((works_man.groupby(pd.Grouper(freq=time_group))['ones'].count()) /
     (df.groupby(pd.Grouper(freq=time_group))['ones'].count())).plot(
         ax=ax, label="Male")
    ((works_woman.groupby(pd.Grouper(freq=time_group))['ones'].count()) /
     (df.groupby(pd.Grouper(freq=time_group))['ones'].count())).plot(
         ax=ax, label="Female")
    xlims = ax.get_xlim()
    ax.hlines(0.5, np.min(xlims), np.max(xlims), lw=0.5)
    ax.set_xlim = xlims
    ax.set_xlabel("Date Acquired")
    ax.set_ylabel("Annual Fraction of Works")
    if title:
        ax.set_title(title)
    ax.legend(loc='best')
    fig.tight_layout()

# %%
plot_gender_breakdown_over_time(combined, title="All artwork")

# %%
plot_total_over_time(combined, title="All artwork")

# %%
plot_gender_fraction_over_time(combined, title="All artwork")

# %% [markdown]
# # Paintings

# %%
paintings = combined[combined.classification.eq('Painting')]

# %%
artists[artists.constituentid.isin(
    paintings.constituentid.value_counts().head(10).index.tolist())]
# Out:
#       constituentid       displayname                         artistbio  \
# 1449           1633     Jean Dubuffet                 French, 1901–1985
# 2153           2419     Philip Guston  American, born Canada. 1913–1980
# 2710           3030         On Kawara               Japanese, 1933–2014
# 3053           3418    Jacob Lawrence               American, 1917–2000
# 3433           3832     Henri Matisse                 French, 1869–1954
# 4133           4609     Pablo Picasso                Spanish, 1881–1973
# 4338           4840      Odilon Redon                 French, 1840–1916
# 5053           5640      Frank Stella               American, born 1936
# 5479           6115       Ben Vautier          French, born Italy. 1935
# 11780         35204  Batiste Madalena               American, 1902–1988
#
#       nationality gender  begindate  enddate wiki_qid         ulan
# 1449       French   male       1901     1985  Q170076  500019113.0
# 2153     American   male       1913     1980  Q701952  500023901.0
# 2710     Japanese   male       1933        0  Q698256  500120601.0
# 3053     American   male       1917     2000  Q355566  500027690.0
# 3433       French   male       1869     1954    Q5589  500017300.0
# 4133      Spanish   male       1881     1973    Q5593  500009666.0
# 4338       French   male       1840     1916  Q154349  500007292.0
# 5053     American   male       1936        0  Q375268  500020533.0
# 5479       French   male       1935        0  Q604546  500011704.0
# 11780    American   male       1902     1988      NaN          NaN

# %%
msno.matrix(paintings.sample(250));

# %%
msno.bar(paintings.sample(1000));

# %%
msno.heatmap(paintings);

# %%
msno.dendrogram(paintings);

# %%
plot_gender_breakdown_over_time(paintings.reset_index(), title="Paintings")

# %%
plot_total_over_time(paintings.reset_index(), title="Paintings")

# %%
plot_gender_fraction_over_time(paintings.reset_index(), title="Paintings")

# %% [markdown]
# # Nationalities

# %%
print("Unique nationalities:", artists.nationality.nunique())
artists.nationality.value_counts().head(20)
# Out:
# Unique nationalities: 129
# American               5404
# German                  973
# French                  883
# British                 868
# Italian                 551
# Japanese                508
# Swiss                   291
# Dutch                   270
# Austrian                247
# Russian                 218
# Nationality unknown     209
# Canadian                205
# Brazilian               168
# Spanish                 157
# Argentine               143
# Polish                  134
# Mexican                 134
# Swedish                 134
# Danish                  121
# Chinese                  97
# Name: nationality, dtype: int64

# %%
combined.constituentid.value_counts().head()
# Out:
# 229     5044
# 710     3237
# 8595    2156
# 1633    1351
# 2002    1314
# Name: constituentid, dtype: int64

# %%
5044 / 2283.
# Out:
# 2.2093736311870344

# %%
combined[combined.constituentid.eq('229')].head()
# Out:
#                                         title constituentid       date  \
# 71450  Tuileries Sanglier / d'apres l'antique           229       1911
# 71451                         Sapin (Trianon)           229    1910-14
# 71452             Versailles, vase par Ballin           229       1902
# 71453                                 Facteur           229  1899-1900
# 71454                             Chiffonnier           229  1899-1900
#
#                                         medium  \
# 71450                     Albumen silver print
# 71451                     Albumen silver print
# 71452               Matte albumen silver print
# 71453  Gelatin silver printing-out-paper print
# 71454                     Albumen silver print
#
#                                      dimensions  \
# 71450          8 11/16 x 6 9/16" (22 x 16.7 cm)
# 71451   Approx. 7 1/8 x 8 5/8" (18.1 x 21.9 cm)
# 71452   Approx. 8 9/16 x 7 1/16" (21.8 x 18 cm)
# 71453  Approx. 8 11/16 x 6 9/16" (22 x 16.7 cm)
# 71454    Approx. 8 11/16 x 7 1/16" (22 x 18 cm)
#
#                                               creditline accessionnumber  \
# 71450  Abbott-Levy Collection. Partial gift of Shirle...        1.1969.1
# 71451  Abbott-Levy Collection. Partial gift of Shirle...       1.1969.10
# 71452  Abbott-Levy Collection. Partial gift of Shirle...      1.1969.100
# 71453  Abbott-Levy Collection. Partial gift of Shirle...     1.1969.1000
# 71454  Abbott-Levy Collection. Partial gift of Shirle...     1.1969.1001
#
#       classification   department dateacquired cataloged  objectid  \
# 71450     Photograph  Photography   1968-03-06         Y     38879
# 71451     Photograph  Photography   1968-03-06         Y     38880
# 71452     Photograph  Photography   1968-03-06         Y     38881
# 71453     Photograph  Photography   1968-03-06         Y     38882
# 71454     Photograph  Photography   1968-03-06         Y     38883
#
#                                               url  \
# 71450  http://www.moma.org/collection/works/38879
# 71451  http://www.moma.org/collection/works/38880
# 71452  http://www.moma.org/collection/works/38881
# 71453  http://www.moma.org/collection/works/38882
# 71454  http://www.moma.org/collection/works/38883
#
#                                             thumbnailurl  circumference_cm  \
# 71450  http://www.moma.org/media/W1siZiIsIjMwMTMwNCJd...               NaN
# 71451  http://www.moma.org/media/W1siZiIsIjMxODEwMSJd...               NaN
# 71452  http://www.moma.org/media/W1siZiIsIjMxODEwMiJd...               NaN
# 71453  http://www.moma.org/media/W1siZiIsIjI4NjE4MiJd...               NaN
# 71454  http://www.moma.org/media/W1siZiIsIjI4NjE4MyJd...               NaN
#
#        depth_cm  diameter_cm  height_cm  length_cm  weight_kg  width_cm  \
# 71450       NaN          NaN        NaN        NaN        NaN       NaN
# 71451       NaN          NaN        NaN        NaN        NaN       NaN
# 71452       NaN          NaN        NaN        NaN        NaN       NaN
# 71453       NaN          NaN        NaN        NaN        NaN       NaN
# 71454       NaN          NaN        NaN        NaN        NaN       NaN
#
#        seat_height_cm  duration_sec   displayname          artistbio  \
# 71450             NaN           NaN  Eugène Atget  French, 1857–1927
# 71451             NaN           NaN  Eugène Atget  French, 1857–1927
# 71452             NaN           NaN  Eugène Atget  French, 1857–1927
# 71453             NaN           NaN  Eugène Atget  French, 1857–1927
# 71454             NaN           NaN  Eugène Atget  French, 1857–1927
#
#       nationality gender  begindate  enddate wiki_qid         ulan
# 71450      French   male       1857     1927  Q322030  500008199.0
# 71451      French   male       1857     1927  Q322030  500008199.0
# 71452      French   male       1857     1927  Q322030  500008199.0
# 71453      French   male       1857     1927  Q322030  500008199.0
# 71454      French   male       1857     1927  Q322030  500008199.0

# %%
combined[combined.constituentid.eq('710')].head()
# Out:
#                                                    title constituentid  date  \
# 34722              Homely Girl, A Life, volumes I and II           710  1992
# 34723  Untitled, plate 1 of 10, from the illustrated ...           710  1992
# 34724  Untitled, plate 2 of 10, from the illustrated ...           710  1992
# 34725  Untitled, plate 3 of 10, from the illustrated ...           710  1992
# 34726  Untitled, plate 4 of 10, from the illustrated ...           710  1992
#
#                             medium  \
# 34722  Two volume illustrated book
# 34723                     Drypoint
# 34724                     Drypoint
# 34725                     Drypoint
# 34726                     Drypoint
#
#                                               dimensions          creditline  \
# 34722  page (each): 11 1/2 × 8 11/16" (29.2 × 22 cm);...  Gift of the artist
# 34723  plate: 6 5/8 x 4 15/16" (16.8 x 12.5 cm); page...  Gift of the artist
# 34724  plate: 7 3/8 x 5 3/8" (18.7 x 13.6 cm); page: ...  Gift of the artist
# 34725  plate: 7 5/16 x 5 3/8" (18.6 x 13.7 cm); page:...  Gift of the artist
# 34726  plate: 7 5/16 x 5 3/8" (18.6 x 13.6 cm); page:...  Gift of the artist
#
#       accessionnumber    classification                  department  \
# 34722  29.1993.A-B.x1  Illustrated Book  Prints & Illustrated Books
# 34723  29.1993.A01.x1  Illustrated Book  Prints & Illustrated Books
# 34724  29.1993.A02.x1  Illustrated Book  Prints & Illustrated Books
# 34725  29.1993.A03.x1  Illustrated Book  Prints & Illustrated Books
# 34726  29.1993.A04.x1  Illustrated Book  Prints & Illustrated Books
#
#       dateacquired cataloged  objectid  \
# 34722   1993-01-18         Y     10114
# 34723   1993-01-18         Y     10115
# 34724   1993-01-18         Y     10116
# 34725   1993-01-18         Y     10117
# 34726   1993-01-18         Y     10118
#
#                                               url  \
# 34722  http://www.moma.org/collection/works/10114
# 34723  http://www.moma.org/collection/works/10115
# 34724  http://www.moma.org/collection/works/10116
# 34725  http://www.moma.org/collection/works/10117
# 34726  http://www.moma.org/collection/works/10118
#
#                                             thumbnailurl  circumference_cm  \
# 34722  http://www.moma.org/media/W1siZiIsIjM0MzU3NCJd...               NaN
# 34723  http://www.moma.org/media/W1siZiIsIjM0MzYzMiJd...               NaN
# 34724  http://www.moma.org/media/W1siZiIsIjM0MzYzMyJd...               NaN
# 34725  http://www.moma.org/media/W1siZiIsIjM0MzYzNCJd...               NaN
# 34726  http://www.moma.org/media/W1siZiIsIjM0MzYzNSJd...               NaN
#
#        depth_cm  diameter_cm  height_cm  length_cm  weight_kg  width_cm  \
# 34722       NaN          NaN       29.2        NaN        NaN      22.0
# 34723       NaN          NaN       16.8        NaN        NaN      12.5
# 34724       NaN          NaN       18.7        NaN        NaN      13.6
# 34725       NaN          NaN       18.6        NaN        NaN      13.7
# 34726       NaN          NaN       18.6        NaN        NaN      13.6
#
#        seat_height_cm  duration_sec       displayname  \
# 34722             NaN           NaN  Louise Bourgeois
# 34723             NaN           NaN  Louise Bourgeois
# 34724             NaN           NaN  Louise Bourgeois
# 34725             NaN           NaN  Louise Bourgeois
# 34726             NaN           NaN  Louise Bourgeois
#
#                               artistbio nationality  gender  begindate  \
# 34722  American, born France. 1911–2010    American  female       1911
# 34723  American, born France. 1911–2010    American  female       1911
# 34724  American, born France. 1911–2010    American  female       1911
# 34725  American, born France. 1911–2010    American  female       1911
# 34726  American, born France. 1911–2010    American  female       1911
#
#        enddate wiki_qid         ulan
# 34722     2010  Q159409  500057350.0
# 34723     2010  Q159409  500057350.0
# 34724     2010  Q159409  500057350.0
# 34725     2010  Q159409  500057350.0
# 34726     2010  Q159409  500057350.0

# %%
works.medium.value_counts().head(20)
# Out:
# Gelatin silver print                       14820
# Lithograph                                  7230
# Albumen silver print                        4774
# Lithograph, printed in color                1657
# Etching                                     1596
# Letterpress                                 1547
# Chromogenic color print                     1544
# Pencil on paper                             1451
# Lithograph, printed in black                1337
# Ink on paper                                1303
# Offset lithograph                           1067
# Oil on canvas                               1057
# Drypoint                                    1035
# Video (color, sound)                        1006
# Woodcut                                      947
# Gelatin silver printing-out-paper print      908
# Screenprint                                  852
# 35mm film                                    692
# Poster                                       651
# Etching, printed in black                    643
# Name: medium, dtype: int64

# %%
works.classification.value_counts().head(100)
# Out:
# Print                             30684
# Photograph                        30644
# Illustrated Book                  26256
# Drawing                           12077
# Design                            11536
# Architecture                       3073
# Video                              2647
# Film                               2438
# Painting                           2283
# Sculpture                          1685
# Multiple                           1091
# Mies van der Rohe Archive           863
# Installation                        776
# Audio                               719
# Periodical                          704
# (not assigned)                      693
# Work on Paper                       171
# Ephemera                            138
# Frank Lloyd Wright Archive           61
# Media                                39
# Performance                          29
# Textile                              27
# Collage                               9
# Poster                                7
# Software                              5
# Photography Research/Reference        5
# Graphic Design                        2
# Publication                           1
# Product Design                        1
# Furniture and Interiors               1
# Architectural Model                   1
# News Clipping                         1
# Name: classification, dtype: int64

# %%
works[works.classification.eq('Painting')]['medium'].value_counts().head(10)
# Out:
# Oil on canvas                        1052
# Synthetic polymer paint on canvas     117
# Oil on composition board               55
# Casein tempera on hardboard            30
# Ink and stamps on postcard             27
# Oil on wood                            21
# Synthetic polymer paint on wood        18
# Tempera on poster board                18
# Oil on linen                           17
# Oil on canvas, two panels              15
# Name: medium, dtype: int64

# %%
works[works.cataloged.eq('Y')]['classification'].value_counts().head(10)
# Out:
# Print               21377
# Photograph          15820
# Drawing             10889
# Design               9162
# Illustrated Book     5230
# Architecture         2625
# Video                2234
# Painting             2233
# Sculpture            1509
# Film                 1206
# Name: classification, dtype: int64

# %%
works[works.classification.eq('Painting') & (works.cataloged.eq('Y'))]['medium'].value_counts().head(10)
# Out:
# Oil on canvas                        1051
# Synthetic polymer paint on canvas     117
# Oil on composition board               55
# Casein tempera on hardboard            30
# Ink and stamps on postcard             27
# Oil on wood                            21
# Oil on linen                           17
# Oil on canvas, two panels              15
# Casein and wax on mahogany             12
# Oil on burlap                          11
# Name: medium, dtype: int64

# %%
works.classification.value_counts() - works[works.cataloged.eq('Y')]['classification'].value_counts()
# Out:
# (not assigned)                      691.0
# Architectural Model                   0.0
# Architecture                        448.0
# Audio                               298.0
# Collage                               1.0
# Design                             2374.0
# Drawing                            1188.0
# Ephemera                             63.0
# Film                               1232.0
# Frank Lloyd Wright Archive           24.0
# Furniture and Interiors               NaN
# Graphic Design                        0.0
# Illustrated Book                  21026.0
# Installation                        391.0
# Media                                32.0
# Mies van der Rohe Archive           270.0
# Multiple                            417.0
# News Clipping                         0.0
# Painting                             50.0
# Performance                           5.0
# Periodical                          209.0
# Photograph                        14824.0
# Photography Research/Reference        4.0
# Poster                                4.0
# Print                              9307.0
# Product Design                        NaN
# Publication                           0.0
# Sculpture                           176.0
# Software                              2.0
# Textile                              10.0
# Video                               413.0
# Work on Paper                       169.0
# Name: classification, dtype: float64

# %% [markdown]
# # Artist age at death

# %%
artists[artists.begindate > 0].begindate.min()
# Out:
# 1730

# %%
artists[artists.enddate > 0].enddate.max()
# Out:
# 2018

# %%
dead_artists = artists[(artists.enddate > 0) & (artists.begindate > 0)].copy()

# %%
dead_artists.head()
# Out:
#    constituentid          displayname  \
# 0              1       Robert Arneson
# 9             11      Jean (Hans) Arp
# 11            13  J. Arrelano Fischer
# 12            15        Folke Arstrom
# 13            16    Cristobal Arteche
#
#                                    artistbio nationality gender  begindate  \
# 0                        American, 1930–1992    American   male       1930
# 9   French, born Germany (Alsace). 1886–1966      French   male       1886
# 11                        Mexican, 1911–1995     Mexican   male       1911
# 12                        Swedish, 1907–1997     Swedish   male       1907
# 13                        Spanish, 1900–1964     Spanish   male       1900
#
#     enddate wiki_qid         ulan
# 0      1992      NaN          NaN
# 9      1966  Q153739  500031000.0
# 11     1995      NaN          NaN
# 12     1997      NaN          NaN
# 13     1964      NaN          NaN

# %%
dead_artists['age'] = dead_artists['enddate'] - dead_artists['begindate']

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.distplot(dead_artists['age'])
fig.tight_layout();

# %%
av_female = np.mean(dead_artists[dead_artists.gender.eq('female')]['age'])
av_male = np.mean(dead_artists[dead_artists.gender.eq('male')]['age'])
fig, ax = plt.subplots(figsize=(12, 8))
sns.distplot(
    dead_artists[dead_artists.gender.eq('male')]['age'],
    hist=False,
    label=f'male {av_male:.2f}')
sns.distplot(
    dead_artists[dead_artists.gender.eq('female')]['age'],
    hist=False,
    label=f'female {av_female:.2f}')
ylims = ax.get_ylim()
ax.vlines(
    av_male,
    ylims[0],
    ylims[1],
    colors=sns.color_palette()[0])
ax.vlines(
    av_female,
    ylims[0],
    ylims[1],
    colors=sns.color_palette()[1])
ax.set_ylabel("Fraction of Population")
ax.set_xlabel("Age at Death")
ax.legend(loc='best')
ax.set_ylim = ylims
fig.tight_layout()
